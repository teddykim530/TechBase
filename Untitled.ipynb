# %%
import os

os.system('C:\\Users\\teddy\\source\\repos\\Project4\\x64\\Debug\\Project4.exe')

import paramiko

try:
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy)
    ssh.connect("127.0.0.1", port="22", username="teddy", password="gusdn147")
    print("connected!!")
    
    stdin, stdout, stderr = ssh.exec_command("cd 문서 ; gcc -o linuxs.exe linuxs.c ; ./linuxs.exe")
    lines = stdout.readlines()
    resultData = ''.join(lines)
    
    print(resultData)
                                                                            
    ssh.close()
    
except Exception as err:
        print(err)
# Out:
# connected!!
#     PID TTY          TIME CMD
#     768 ?        00:00:00 systemd
#     769 ?        00:00:00 (sd-pam)
#     779 ?        00:00:02 pulseaudio
#     781 ?        00:00:00 tracker-miner-f
#     785 ?        00:00:00 dbus-daemon
#     787 ?        00:00:00 gnome-keyring-d
#     800 ?        00:00:00 gvfsd
#     806 ?        00:00:00 gvfsd-fuse
#     817 ?        00:00:00 gvfs-udisks2-vo
#     822 ?        00:00:00 gvfs-afc-volume
#     831 ?        00:00:00 gvfs-goa-volume
#     835 ?        00:00:00 goa-daemon
#     997 ?        00:00:00 goa-identity-se
#    1007 ?        00:00:00 gvfs-mtp-volume
#    1014 ?        00:00:00 gvfs-gphoto2-vo
#    1150 ?        00:00:00 ssh-agent
#    1205 ?        00:00:00 at-spi-bus-laun
#    1213 ?        00:00:00 dbus-daemon
#    1390 ?        00:00:00 gnome-session-c
#    1401 ?        00:00:00 gnome-session-b
#    1470 ?        00:01:26 gnome-shell
#    1582 ?        00:00:00 gvfsd-metadata
#    1603 ?        00:00:02 ibus-daemon
#    1607 ?        00:00:00 ibus-dconf
#    1608 ?        00:00:00 ibus-extension-
#    1612 ?        00:00:00 ibus-x11
#    1615 ?        00:00:00 ibus-portal
#    1627 ?        00:00:00 at-spi2-registr
#    1631 ?        00:00:00 xdg-permission-
#    1636 ?        00:00:00 gnome-shell-cal
#    1642 ?        00:00:00 evolution-sourc
#    1652 ?        00:00:00 evolution-calen
#    1671 ?        00:00:00 dconf-service
#    1672 ?        00:00:00 evolution-addre
#    1693 ?        00:00:00 gjs
#    1699 ?        00:00:00 gvfsd-trash
#    1725 ?        00:00:00 gsd-a11y-settin
#    1726 ?        00:00:00 gsd-color
#    1727 ?        00:00:00 gsd-datetime
#    1728 ?        00:00:00 gsd-housekeepin
#    1729 ?        00:00:00 gsd-keyboard
#    1730 ?        00:00:00 gsd-media-keys
#    1731 ?        00:00:00 gsd-power
#    1732 ?        00:00:00 gsd-print-notif
#    1733 ?        00:00:00 gsd-rfkill
#    1736 ?        00:00:00 gsd-screensaver
#    1741 ?        00:00:00 gsd-sharing
#    1743 ?        00:00:00 gsd-smartcard
#    1747 ?        00:00:00 gsd-sound
#    1748 ?        00:00:00 gsd-usb-protect
#    1753 ?        00:00:00 gsd-wacom
#    1757 ?        00:00:00 gsd-wwan
#    1763 ?        00:00:00 gsd-xsettings
#    1801 ?        00:00:00 evolution-alarm
#    1810 ?        00:00:00 gsd-disk-utilit
#    1839 ?        00:00:00 gsd-printer
#    1885 ?        00:00:00 ibus-engine-han
#    1951 ?        00:00:00 gvfsd-recent
#    1971 ?        00:00:00 update-notifier
#    3023 ?        00:00:03 update-manager
#    7198 ?        00:00:00 ibus-engine-sim
#    7245 ?        00:00:02 gnome-terminal-
#    7416 ?        00:00:01 nautilus
#    7436 ?        00:00:00 ssh-agent
#    9180 ?        00:00:00 sshd
#    9181 ?        00:00:00 bash
#    9187 ?        00:00:00 tracker-store
#    9188 ?        00:00:00 linuxs.exe
#    9191 ?        00:00:00 sh
#    9194 ?        00:00:00 ps
# 	Hardware information
# =====================================
# 업타임: 0 days
# 메모리 총계: 4023440 KB
# 사용가능 메모리: 1343364KB
# 현재 프로세스 갯수: 475
# CPU 갯수: 1
#
# 시스템 이름: Linux
# 노드명: teddy-VirtualBox
# 커널버전: 5.11.0-40-generic
# 릴리즈버전: #44~20.04.2-Ubuntu SMP Tue Oct 26 18:07:44 UTC 2021
# 프로세서타입: x86_64
#
# =====================================
# 	Process information
# =====================================
#
# =====================================
# 	file list information
# =====================================
# file.ex
# a.out
# sysinfo.c
# Linux.odt
# GNOME
# process3.exe
# sysinfo_ex
# linuxs.c
# dir
# filelist.c
# network.ex
# TechBase
# .aaa.swp
# .
# linuxs.exe
# aaa
# network.c
# process3.c
# prac.c
# linuxs
# ..
# process.c
# 무제
#
# =====================================
# 	network information
# =====================================
# IP Address : 10.0.2.15
